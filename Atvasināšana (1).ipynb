# %% [markdown]
# Laboratorijas darbs "Atvasināšana"
# Nauris Silkāns REBCO1
# Apliecības NR: 181REB264

# %%
import numpy as np
import matplotlib as plt
from math import atan

# %% [markdown]
# Definē funkxiju, norāda dotā intervāla(-2:2) sākuma vērtību un soli, ar kuru iet uz priekšu"

# %%
def f(x):
    return atan(-x)
x0=-2
h=0.01
t= np.arange(-2, 2, h)

# %% [markdown]
# Nosaka funkcijas pirmās un otrās kārtas atvasinājumu pēc "Skatīšanās uz priekšu" metodes. Izvada funkcijas argumenta vērtību, funkcijas vērtību, pirmās un otrās kārtas atvasinājumu.

# %%
while x0<2:
    if x0==0:
        fprim=(atan(-(x0+h))-atan(-x0))/h
        f2prim=(atan(-(x0+2*h)) - 2*(atan(-(x0+h))) +(atan(-x0))) / h**2
        ff=atan(-x0)
    x0=x0+h
    fprim= fprim=(atan(-(x0+h))-atan(-x0))/h
    f2prim=(atan(-(x0+2*h)) - 2*(atan(-(x0+h))) +(atan(-x0))) / h**2
    ff=atan(-x0)
    print("Argumenta vertiba: ",x0,",Originalas funkcija vertiba",ff ,"atvasinajuma vertiba: ", fprim, "otas kartas atvasinajuma vertiba: ", f2prim)
# Out:
# Argumenta vertiba:  -1.99 ,Originalas funkcija vertiba 1.1051406883644943 atvasinajuma vertiba:  -0.20242067814972842 otas kartas atvasinajuma vertiba:  -0.1635684751333244
# Argumenta vertiba:  -1.98 ,Originalas funkcija vertiba 1.103116481582997 atvasinajuma vertiba:  -0.20405636290106166 otas kartas atvasinajuma vertiba:  -0.165387108292947
# Argumenta vertiba:  -1.97 ,Originalas funkcija vertiba 1.1010759179539864 atvasinajuma vertiba:  -0.20571023398399113 otas kartas atvasinajuma vertiba:  -0.16722974170324534
# Argumenta vertiba:  -1.96 ,Originalas funkcija vertiba 1.0990188156141465 atvasinajuma vertiba:  -0.20738253140102358 otas kartas atvasinajuma vertiba:  -0.1690967018785905
# Argumenta vertiba:  -1.95 ,Originalas funkcija vertiba 1.0969449903001363 atvasinajuma vertiba:  -0.2090734984198095 otas kartas atvasinajuma vertiba:  -0.17098831854855945
# ...
